# %%
import pandas as pd

df = pd.read_csv("Global Superstore.csv")
df.head()
# Out:
#           Category         City        Country Customer ID     Customer Name  \
# 0  Office Supplies  Los Angeles  United States   LS-172304  Lycoris Saunders
# 1  Office Supplies  Los Angeles  United States   MV-174854     Mark Van Huff
# 2  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 3  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 4  Office Supplies  Los Angeles  United States   AP-109154    Arthur Prichep
#
#    Discount Market  ji_lu-shu Order Date        Order ID  ... Sales   Segment  \
# 0       0.0     US          1    00:00.0  CA-2011-130813  ...    19  Consumer
# 1       0.0     US          1    00:00.0  CA-2011-148614  ...    19  Consumer
# 2       0.0     US          1    00:00.0  CA-2011-118962  ...    21  Consumer
# 3       0.0     US          1    00:00.0  CA-2011-118962  ...   111  Consumer
# 4       0.0     US          1    00:00.0  CA-2011-146969  ...     6  Consumer
#
#   Ship Date       Ship Mode  Shipping Cost       State  Sub-Category  Year  \
# 0   00:00.0    Second Class           4.37  California         Paper  2011
# 1   00:00.0  Standard Class           0.94  California         Paper  2011
# 2   00:00.0  Standard Class           1.81  California         Paper  2011
# 3   00:00.0  Standard Class           4.59  California         Paper  2011
# 4   00:00.0  Standard Class           1.32  California         Paper  2011
#
#          Market2 weeknum
# 0  North America       2
# 1  North America       4
# 2  North America      32
# 3  North America      32
# 4  North America      40
#
# [5 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Category        51290 non-null  str
#  1   City            51290 non-null  str
#  2   Country         51290 non-null  str
#  3   Customer ID     51290 non-null  str
#  4   Customer Name   51290 non-null  str
#  5   Discount        51290 non-null  float64
#  6   Market          51290 non-null  str
#  7   ji_lu-shu       51290 non-null  int64
#  8   Order Date      51290 non-null  str
#  9   Order ID        51290 non-null  str
#  10  Order Priority  51290 non-null  str
#  11  Product ID      51290 non-null  str
#  12  Product Name    51290 non-null  str
#  13  Profit          51290 non-null  float64
#  14  Quantity        51290 non-null  int64
#  15  Region          51290 non-null  str
#  16  Row ID          51290 non-null  int64
#  17  Sales           51290 non-null  int64
#  18  Segment         51290 non-null  str
#  19  Ship Date       51290 non-null  str
#  20  Ship Mode       51290 non-null  str
#  21  Shipping Cost   51290 non-null  float64
#  22  State           51290 non-null  str
#  23  Sub-Category    51290 non-null  str
#  24  Year            51290 non-null  int64
#  25  Market2         51290 non-null  str
#  26  weeknum         51290 non-null  int64
# dtypes: float64(3), int64(6), str(18)
# memory usage: 10.6 MB

# %%
df.describe()
# Out:
#            Discount  ji_lu-shu        Profit      Quantity       Row ID  \
# count  51290.000000    51290.0  51290.000000  51290.000000  51290.00000
# mean       0.142908        1.0     28.610982      3.476545  25645.50000
# std        0.212280        0.0    174.340972      2.278766  14806.29199
# min        0.000000        1.0  -6599.978000      1.000000      1.00000
# 25%        0.000000        1.0      0.000000      2.000000  12823.25000
# 50%        0.000000        1.0      9.240000      3.000000  25645.50000
# 75%        0.200000        1.0     36.810000      5.000000  38467.75000
# max        0.850000        1.0   8399.976000     14.000000  51290.00000
#
#               Sales  Shipping Cost          Year       weeknum
# count  51290.000000   51290.000000  51290.000000  51290.000000
# mean     246.498440      26.375818   2012.777208     31.287112
# std      487.567175      57.296810      1.098931     14.429795
# min        0.000000       0.002000   2011.000000      1.000000
# 25%       31.000000       2.610000   2012.000000     20.000000
# 50%       85.000000       7.790000   2013.000000     33.000000
# 75%      251.000000      24.450000   2014.000000     44.000000
# max    22638.000000     933.570000   2014.000000     53.000000

# %%
df.isnull().sum()
# Out:
# Category          0
# City              0
# Country           0
# Customer ID       0
# Customer Name     0
# Discount          0
# Market            0
# ji_lu-shu         0
# Order Date        0
# Order ID          0
# Order Priority    0
# Product ID        0
# Product Name      0
# Profit            0
# Quantity          0
# Region            0
# Row ID            0
# Sales             0
# Segment           0
# Ship Date         0
# Ship Mode         0
# Shipping Cost     0
# State             0
# Sub-Category      0
# Year              0
# Market2           0
# weeknum           0
# dtype: int64

# %%
df['Category'].unique()

df['Region'].unique()
# Out:
# <StringArray>
# [          'West',           'East',          'South',        'Central',
#          'Africa',   'Central Asia',     'North Asia',      'Caribbean',
#           'North',           'EMEA',        'Oceania', 'Southeast Asia',
#          'Canada']
# Length: 13, dtype: str

# %%
df.groupby('Category')['Sales'].sum()
# Out:
# Category
# Furniture          4110884
# Office Supplies    3787330
# Technology         4744691
# Name: Sales, dtype: int64

# %%
df.groupby('Category')['Profit'].sum()
# Out:
# Category
# Furniture          285204.72380
# Office Supplies    518473.83430
# Technology         663778.73318
# Name: Profit, dtype: float64

# %%
df.groupby('Region')['Sales'].sum()
# Out:
# Region
# Africa             783776
# Canada              66932
# Caribbean          324281
# Central           2822399
# Central Asia       752839
# EMEA               806184
# East               678834
# North             1248192
# North Asia         848349
# Oceania           1100207
# South             1600960
# Southeast Asia     884438
# West               725514
# Name: Sales, dtype: int64

# %%
df.corr(numeric_only=True)
# Out:
#                Discount  ji_lu-shu    Profit  Quantity    Row ID     Sales  \
# Discount       1.000000        NaN -0.316490 -0.019875  0.087594 -0.086728
# ji_lu-shu           NaN        NaN       NaN       NaN       NaN       NaN
# Profit        -0.316490        NaN  1.000000  0.104365 -0.019037  0.484923
# Quantity      -0.019875        NaN  0.104365  1.000000 -0.173483  0.313580
# Row ID         0.087594        NaN -0.019037 -0.173483  1.000000 -0.043888
# Sales         -0.086728        NaN  0.484923  0.313580 -0.043888  1.000000
# Shipping Cost -0.079055        NaN  0.354441  0.272649 -0.039076  0.768075
# Year          -0.005894        NaN  0.002626 -0.005049 -0.000921 -0.002902
# weeknum       -0.000217        NaN -0.000182  0.020839 -0.028776  0.001947
#
#                Shipping Cost      Year   weeknum
# Discount           -0.079055 -0.005894 -0.000217
# ji_lu-shu                NaN       NaN       NaN
# Profit              0.354441  0.002626 -0.000182
# Quantity            0.272649 -0.005049  0.020839
# Row ID             -0.039076 -0.000921 -0.028776
# Sales               0.768075 -0.002902  0.001947
# Shipping Cost       1.000000 -0.003137  0.005347
# Year               -0.003137  1.000000 -0.019627
# weeknum             0.005347 -0.019627  1.000000

# %%
df[df['Profit'] < 0]
# Out:
#          Category                 City        Country Customer ID  \
# 29009  Technology                Paris         France   RC-198252
# 29012  Technology              Taverny         France   TB-211752
# 29018  Technology   Tremblay-en-France         France   DH-130752
# 29021  Technology           Guyancourt         France   MH-174552
# 29024  Technology  Le Plessis-Robinson         France   AA-104802
# ...           ...                  ...            ...         ...
# 51156  Technology          Los Angeles  United States   LH-171554
# 51163  Technology          Los Angeles  United States   SC-202304
# 51164  Technology          Los Angeles  United States   SC-202304
# 51180  Technology          Los Angeles  United States   MG-176804
# 51186  Technology          Los Angeles  United States   MG-181454
#
#            Customer Name  Discount Market  ji_lu-shu Order Date  \
# 29009        Roy Collins      0.15     EU          1    00:00.0
# 29012      Thomas Boland      0.15     EU          1    00:00.0
# 29018      Dave Hallsten      0.15     EU          1    00:00.0
# 29021      Mark Hamilton      0.15     EU          1    00:00.0
# 29024       Andrew Allen      0.15     EU          1    00:00.0
# ...                  ...       ...    ...        ...        ...
# 51156   Logan Haushalter      0.20     US          1    00:00.0
# 51163         Scot Coram      0.20     US          1    00:00.0
# 51164         Scot Coram      0.20     US          1    00:00.0
# 51180  Maureen Gastineau      0.20     US          1    00:00.0
# 51186    Mike Gockenbach      0.20     US          1    00:00.0
#
#               Order ID  ... Sales      Segment Ship Date       Ship Mode  \
# 29009  IT-2011-2185983  ...   684     Consumer   00:00.0        Same Day
# 29012  ES-2011-5235241  ...   538    Corporate   00:00.0        Same Day
# 29018  ES-2011-4614329  ...    95    Corporate   00:00.0     First Class
# 29021  ES-2012-2141914  ...   286     Consumer   00:00.0    Second Class
# 29024  IT-2012-5602177  ...  1894     Consumer   00:00.0    Second Class
# ...                ...  ...   ...          ...       ...             ...
# 51156   US-2013-139486  ...    55     Consumer   00:00.0     First Class
# 51163   US-2013-126452  ...    32    Corporate   00:00.0  Standard Class
# 51164   US-2013-126452  ...    92    Corporate   00:00.0  Standard Class
# 51180   US-2014-109316  ...    18  Home Office   00:00.0     First Class
# 51186   CA-2014-108574  ...   129     Consumer   00:00.0  Standard Class
#
#        Shipping Cost          State  Sub-Category  Year        Market2 weeknum
# 29009         100.32  Ile-de-France        Phones  2011             EU      18
# 29012          70.11  Ile-de-France       Copiers  2011             EU      35
# 29018           5.53  Ile-de-France      Machines  2011             EU      49
# 29021          60.78  Ile-de-France        Phones  2012             EU      23
# 29024         111.55  Ile-de-France       Copiers  2012             EU      35
# ...              ...            ...           ...   ...            ...     ...
# 51156          17.61     California        Phones  2013  North America      21
# 51163           4.74     California        Phones  2013  North America      34
# 51164          14.61     California        Phones  2013  North America      34
# 51180           0.94     California        Phones  2014  North America      24
# 51186          11.24     California        Phones  2014  North America      41
#
# [12544 rows x 27 columns]
